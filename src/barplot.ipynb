# %%
from barplot import generate_bar_chart
generate_bar_chart("maneuvers_10_50-60_59.csv")
generate_bar_chart("planes_20-35_10_19.csv")

# %%
from barplot import generate_bar_chart
generate_bar_chart("maneuvers_10_50-60_59.csv")
# generate_bar_chart("planes_20-35_10_19.csv")

# %%
from barplot import comparison_bar_chart
comparison_bar_chart("maneuvers_10_50-60_59.csv")
comparison_bar_chart("planes_20-35_10_19.csv", True)

# %%
from barplot import avg_times_and_sols_num, comparison_bar_chart
avg_times_and_sols_num("maneuvers_10_50-60_59.csv")
avg_times_and_sols_num("planes_20-35_10_19.csv", True)

# %%
avg_times_and_sols_num("density_10_30_20-35.csv", True)
comparison_bar_chart("density_10_30_20-35.csv")

# %%
avg_times_and_sols_num("density_20_20_15-30.csv", True)
comparison_bar_chart("density_20_20_15-30.csv")
